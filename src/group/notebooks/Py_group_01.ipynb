# %%
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np
from sympy import *
init_printing(use_unicode=True)

# %%
x, y, z = symbols('x y z')

# %%
diff(exp(x**2), x)
# Out:
#      ⎛ 2⎞
#      ⎝x ⎠
# 2⋅x⋅ℯ

# %%
expr = exp(x*y*z)
diff(expr, x, y, y, z, z, z, z)
# Out:
#  3  2 ⎛ 3  3  3       2  2  2                ⎞  x⋅y⋅z
# x ⋅y ⋅⎝x ⋅y ⋅z  + 14⋅x ⋅y ⋅z  + 52⋅x⋅y⋅z + 48⎠⋅ℯ

# %%
deriv = Derivative(expr, x, y, y, z, 4)

# %%
deriv
# Out:
#      7
#     ∂     ⎛ x⋅y⋅z⎞
# ──────────⎝ℯ     ⎠
#   4   2
# ∂z  ∂y  ∂x

# %%
integrate(exp(-x), (x, 0, oo))
# Out:
# 1

# %%
expr2 = Integral((x**4 + x**2*exp(x) - x**2 - 2*x*exp(x) - 2*x -
    exp(x))*exp(x)/((x - 1)**2*(x + 1)**2*(exp(x) + 1)), x)

# %%
limit((cos(x) - 1)/x, x, 0)
# Out:
# 0

# %%
Matrix([[1, -1], [3, 4], [0, 2]])
# Out:
# ⎡1  -1⎤
# ⎢     ⎥
# ⎢3  4 ⎥
# ⎢     ⎥
# ⎣0  2 ⎦

# %%
latex(expr2)
# Out:
# '\\int \\frac{\\left(x^{4} + x^{2} e^{x} - x^{2} - 2 x e^{x} - 2 x - e^{x}\\right) e^{x}}{\\left(x - 1\\right)^{2} \\left(x + 1\\right)^{2} \\left(e^{x} + 1\\right)}\\, dx'

# %%
expr1 = 1/sqrt(1+x)
expr2 = 1/sqrt(1-x)

# %%
texpr1 = series(expr1, x, 0, 6, "+")

# %%
texpr2 = series(expr2, x, 0, 6, "+")

# %%
expr3 = texpr2.subs(x, -2*y - z**2)

# %%
expand(expr3, y)
# Out:
#      2      4      6       8       10            2         4         6         ↪
#     z    3⋅z    5⋅z    35⋅z    63⋅z         3⋅y⋅z    15⋅y⋅z    35⋅y⋅z    315⋅y ↪
# 1 - ── + ──── - ──── + ───── - ────── - y + ────── - ─────── + ─────── - ───── ↪
#     2     8      16     128     256           2         8        16        128 ↪
#
# ↪   8      2       2  2        2  4        2  6      3       3  2        3  4  ↪
# ↪ ⋅z    3⋅y    15⋅y ⋅z    105⋅y ⋅z    315⋅y ⋅z    5⋅y    35⋅y ⋅z    315⋅y ⋅z   ↪
# ↪ ─── + ──── - ──────── + ───────── - ───────── - ──── + ──────── - ─────────  ↪
# ↪        2        4          16          32        2        4          16      ↪
#
# ↪       4        4  2       5                                                  ↪
# ↪   35⋅y    315⋅y ⋅z    63⋅y     ⎛ 6    5  2    4  4    3  6    2  8      10   ↪
# ↪ + ───── - ───────── - ───── + O⎝y  + y ⋅z  + y ⋅z  + y ⋅z  + y ⋅z  + y⋅z   + ↪
# ↪     8        16         8                                                    ↪
#
# ↪
# ↪   12                 ⎞
# ↪  z  ; (y, z) → (0, 0)⎠
# ↪
