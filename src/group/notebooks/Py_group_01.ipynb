# %%
import sys
print(sys.version)
# Out:
# 3.12.6 | packaged by conda-forge | (main, Sep 22 2024, 14:08:13) [Clang 17.0.6 ]

# %%
pwd()
# Out:
# '/Users/jiyong/Documents/Projects/MathematicalPhysics/src/group/notebooks'
